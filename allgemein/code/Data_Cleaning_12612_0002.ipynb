# %%
import numpy as np
import pandas as pd 
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.linear_model import LinearRegression

# %%
raw_data = pd.read_csv('12612-0002.csv')
raw_data
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25768\3224374177.py in <module>
# ----> 1 raw_data = pd.read_csv('12612-0002.csv')
#       2 raw_data
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
raw_data = pd.read_csv('12612-0002.csv', skiprows=5,  encoding='ISO-8859-1', delimiter=';')
raw_data
# Out:
#                                     Unnamed: 0 Unnamed: 1  männlich  weiblich  \
# 0                                         2019     Januar   32598.0   30677.0
# 1                                         2019    Februar   29273.0   27911.0
# 2                                         2019       März   31703.0   29976.0
# 3                                         2019      April   32130.0   30504.0
# 4                                         2019        Mai   33313.0   31629.0
# 5                                         2019       Juni   34383.0   32333.0
# 6                                         2019       Juli   37427.0   35233.0
# 7                                         2019     August   36727.0   34835.0
# 8                                         2019  September   36021.0   34036.0
# 9                                         2019    Oktober   34043.0   32787.0
# 10                                        2019   November   30936.0   29624.0
# ...

# %%
raw_data = pd.read_csv('12612-0002.csv', skiprows=5, nrows=50, encoding='ISO-8859-1', delimiter=';')
raw_data
# Out:
#     Unnamed: 0 Unnamed: 1  männlich  weiblich  Insgesamt
# 0         2019     Januar     32598     30677      63275
# 1         2019    Februar     29273     27911      57184
# 2         2019       März     31703     29976      61679
# 3         2019      April     32130     30504      62634
# 4         2019        Mai     33313     31629      64942
# 5         2019       Juni     34383     32333      66716
# 6         2019       Juli     37427     35233      72660
# 7         2019     August     36727     34835      71562
# 8         2019  September     36021     34036      70057
# 9         2019    Oktober     34043     32787      66830
# 10        2019   November     30936     29624      60560
# 11        2019   Dezember     30738     29253      59991
# 12        2020     Januar     32664     31049      63713
# 13        2020    Februar     30188     28512      58700
# 14        2020       März     31646     30584      62230
# ...

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  50 non-null     int64
#  1   Unnamed: 1  50 non-null     object
#  2   männlich    50 non-null     int64
#  3   weiblich    50 non-null     int64
#  4   Insgesamt   50 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 2.1+ KB
